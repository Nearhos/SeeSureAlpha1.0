# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
harunshimanto_epileptic_seizure_recognition_path = kagglehub.dataset_download('harunshimanto/epileptic-seizure-recognition')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/harunshimanto/epileptic-seizure-recognition?dataset_version_number=2...
# 100%|██████████| 2.77M/2.77M [00:00<00:00, 143MB/s]
# Extracting files...
# Data source import complete.

# %%
# %%html
# <style>
# @import url('https://fonts.googleapis.com/css?family=Ewert|Roboto&effect=3d|ice|');
# body {background-color: gainsboro;}
# a {color: #37c9e1; font-family: 'Roboto';}
# h1 {color: #37c9e1; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #aaa;}
# h2, h3 {color: slategray; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #aaa;}
# h4 {color: #818286; font-family: 'Roboto';}
# span {font-family:'Roboto'; color:black; text-shadow: 5px 5px 5px #aaa;}
# div.output_area pre{font-family:'Roboto'; font-size:110%; color:lightblue;}
# </style>
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Ewert|Roboto&effect=3d|ice|');
# body {background-color: gainsboro;}
# a {color: #37c9e1; font-family: 'Roboto';}
# h1 {color: #37c9e1; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #aaa;}
# h2, h3 {color: slategray; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #aaa;}
# h4 {color: #818286; font-family: 'Roboto';}
# span {font-family:'Roboto'; color:black; text-shadow: 5px 5px 5px #aaa;}
# div.output_area pre{font-family:'Roboto'; font-size:110%; color:lightblue;}
# </style>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

# %%
ESR = pd.read_csv('/Epileptic Seizure Recognition.csv')

# %%
ESR.head()
# Out:
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
cols = ESR.columns
tgt = ESR.y
tgt[tgt>1]=0
ax = sn.countplot(tgt,label="Count")
non_seizure, seizure = tgt.value_counts()
print('The number of trials for the non-seizure class is:', non_seizure)
print('The number of trials for the seizure class is:', seizure)
# Out:
# <ipython-input-11-ede7aa9cc3d7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tgt[tgt>1]=0
# The number of trials for the non-seizure class is: 9200
# The number of trials for the seizure class is: 2300

# %%
ESR.isnull().sum()

# %%
ESR.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# std      161.328725    161.467837    162.11912    162.03336    160.436352
# min    -1757.000000  -1832.000000  -1778.00000  -1840.00000  -1867.000000
# 25%      -54.000000    -54.000000    -55.00000    -55.00000    -54.000000
# 50%       -8.000000     -8.000000     -8.00000     -7.00000     -7.000000
# 75%       36.000000     35.000000     36.00000     36.00000     35.250000
# max     1816.000000   2047.000000   2047.00000   2047.00000   2047.000000
#
#        ...          X170          X171          X172          X173  \
# count  ...  11500.000000  11500.000000  11500.000000  11500.000000
# mean   ...    -10.145739    -11.630348    -12.943478    -13.668870
# std    ...    164.652883    166.149790    168.554058    168.556486
# min    ...  -1867.000000  -1865.000000  -1642.000000  -1723.000000
# 25%    ...    -55.000000    -56.000000    -56.000000    -56.000000
# 50%    ...     -9.000000    -10.000000    -10.000000    -10.000000
# 75%    ...     34.000000     34.000000     33.000000     33.000000
# max    ...   1777.000000   1472.000000   1319.000000   1436.000000
#
#                X174          X175          X176          X177          X178  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -13.363304    -13.045043    -12.705130    -12.426000    -12.195652
# std      167.257290    164.241019    162.895832    162.886311    164.852015
# min    -1866.000000  -1863.000000  -1781.000000  -1727.000000  -1829.000000
# 25%      -55.000000    -56.000000    -55.000000    -55.000000    -55.000000
# 50%      -10.000000     -9.000000     -9.000000     -9.000000     -9.000000
# 75%       34.000000     34.000000     34.000000     34.000000     34.000000
# max     1733.000000   1958.000000   2047.000000   2047.000000   1915.000000
#
#                   y
# count  11500.000000
# mean       0.200000
# std        0.400017
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 179 columns]

# %%
X = ESR.iloc[:,1:179].values
X.shape
# Out:
# (11500, 178)

# %%
plt.subplot(511)
plt.plot(X[1,:])
plt.title('Classes')
plt.ylabel('uV')
plt.subplot(512)
plt.plot(X[7,:])
plt.subplot(513)
plt.plot(X[12,:])
plt.subplot(514)
plt.plot(X[0,:])
plt.subplot(515)
plt.plot(X[2,:])
plt.xlabel('Samples')

# %%
y = ESR.iloc[:,179].values
y
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
y[y>1]=0
y
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_pred_log_reg = clf.predict(X_test)
acc_log_reg = round(clf.score(X_train, y_train) * 100, 2)
print (str(acc_log_reg) + ' %')
# Out:
# 82.71 %
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(X_train, y_train)
y_pred_svc = clf.predict(X_test)
acc_svc = round(clf.score(X_train, y_train) * 100, 2)
print (str(acc_svc) + '%')
# Out:
# 98.43%

# %%
from sklearn.svm import SVC, LinearSVC
clf = LinearSVC()
clf.fit(X_train, y_train)
y_pred_linear_svc = clf.predict(X_test)
acc_linear_svc = round(clf.score(X_train, y_train) * 100, 2)
print (str(acc_linear_svc) + '%')
# Out:
# 82.5%

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier()
clf.fit(X_train, y_train)
y_pred_knn = clf.predict(X_test)
acc_knn = round(clf.score(X_train, y_train) * 100, 2)
print (str(acc_knn)+'%')
# Out:
# 94.02%

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred_gnb = clf.predict(X_test)
acc_gnb = round(clf.score(X_train, y_train) * 100, 2)
print (str(acc_gnb) + '%')
# Out:
# 95.88%

# %%
#Importing keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=80, kernel_initializer='uniform', activation='relu', input_dim=178))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
classifier.add(Dense(units=80, kernel_initializer='uniform', activation='relu'))

# %%
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

#Fitting the ANN to the training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9294 - loss: 0.3258
# Epoch 2/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9690 - loss: 0.0985
# Epoch 3/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9776 - loss: 0.0694
# Epoch 4/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9749 - loss: 0.0713
# Epoch 5/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9803 - loss: 0.0560
# Epoch 6/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9815 - loss: 0.0527
# Epoch 7/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9869 - loss: 0.0450
# Epoch 8/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9885 - loss: 0.0343
# Epoch 9/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9892 - loss: 0.0301
# Epoch 10/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9903 - loss: 0.0332
# Epoch 11/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9885 - loss: 0.0345
# Epoch 12/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9918 - loss: 0.0234
# Epoch 13/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9915 - loss: 0.0264
# Epoch 14/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9913 - loss: 0.0227
# Epoch 15/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9960 - loss: 0.0122
# Epoch 16/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9925 - loss: 0.0235
# Epoch 17/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.0233
# Epoch 18/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9954 - loss: 0.0145
# Epoch 19/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9954 - loss: 0.0145
# Epoch 20/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9956 - loss: 0.0104
# Epoch 21/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9943 - loss: 0.0173
# Epoch 22/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9946 - loss: 0.0190
# Epoch 23/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9959 - loss: 0.0127
# Epoch 24/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9976 - loss: 0.0068
# Epoch 25/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9964 - loss: 0.0104
# Epoch 26/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9915 - loss: 0.0221
# Epoch 27/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0063
# Epoch 28/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9991 - loss: 0.0039
# Epoch 29/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9981 - loss: 0.0052
# Epoch 30/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9942 - loss: 0.0201
# Epoch 31/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0054
# Epoch 32/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0102
# Epoch 33/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9986 - loss: 0.0057
# Epoch 34/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9995 - loss: 0.0019
# Epoch 35/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9964 - loss: 0.0152
# Epoch 36/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9984 - loss: 0.0054
# Epoch 37/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9992 - loss: 0.0027
# Epoch 38/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9995 - loss: 0.0025
# Epoch 39/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9915 - loss: 0.0385
# Epoch 40/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9986 - loss: 0.0040
# Epoch 41/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9990 - loss: 0.0032
# Epoch 42/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0051
# Epoch 43/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9999 - loss: 5.9673e-04
# Epoch 44/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9962 - loss: 0.0117
# Epoch 45/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9976 - loss: 0.0154
# Epoch 46/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9972 - loss: 0.0080
# Epoch 47/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9988 - loss: 0.0026
# Epoch 48/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9978 - loss: 0.0072
# Epoch 49/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9999 - loss: 0.0011
# Epoch 50/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9960 - loss: 0.0181
# Epoch 51/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9983 - loss: 0.0042
# Epoch 52/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 5.4358e-04
# Epoch 53/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.6636e-04
# Epoch 54/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 7.6448e-05
# Epoch 55/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 5.9446e-05
# Epoch 56/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 4.3684e-05
# Epoch 57/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 1.0000 - loss: 2.1854e-05
# Epoch 58/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.4822e-05
# Epoch 59/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.0898e-04
# Epoch 60/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9884 - loss: 0.0763
# Epoch 61/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9966 - loss: 0.0094
# Epoch 62/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9995 - loss: 0.0011
# Epoch 63/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 5.3479e-04
# Epoch 64/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 1.7431e-04
# Epoch 65/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 1.0556e-04
# Epoch 66/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 5.7681e-05
# Epoch 67/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 3.0644e-05
# Epoch 68/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 2.6124e-05
# Epoch 69/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 2.0805e-05
# Epoch 70/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.0720e-05
# Epoch 71/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 5.5179e-06
# Epoch 72/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 5.4478e-06
# Epoch 73/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9957 - loss: 0.0323
# Epoch 74/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9972 - loss: 0.0119
# Epoch 75/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9997 - loss: 5.9447e-04
# Epoch 76/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9999 - loss: 5.2526e-04
# Epoch 77/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9965 - loss: 0.0180
# Epoch 78/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0122
# Epoch 79/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9987 - loss: 0.0095
# Epoch 80/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.8528e-04
# Epoch 81/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 8.0687e-05
# Epoch 82/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.8988e-05
# Epoch 83/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 3.8020e-05
# Epoch 84/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 2.2181e-05
# Epoch 85/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 2.0931e-05
# Epoch 86/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 8.4636e-06
# Epoch 87/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 7.7056e-06
# Epoch 88/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 4.8795e-06
# Epoch 89/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 3.6133e-06
# Epoch 90/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 3.1790e-06
# Epoch 91/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.3655e-06
# Epoch 92/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 8.8908e-07
# Epoch 93/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 3.7140e-07
# Epoch 94/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 4.6166e-07
# Epoch 95/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.8467e-07
# Epoch 96/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.0352e-07
# Epoch 97/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 6.8632e-08
# Epoch 98/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 4.2615e-08
# Epoch 99/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 2.5567e-08
# Epoch 100/100
# 920/920 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 2.1374e-08

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
acc_ANN = round(clf.score(X_train, y_train) * 100, 2)
print (str(acc_ANN) + '%')
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 82.71%

# %%
from sklearn.decomposition import PCA
pca = PCA()
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)
acc_PCA = round(pca.score(X_train, y_train) )
print (str(acc_PCA) + '%')

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Support Vector Machines','ANN',
              'KNN', 'Naive Bayes', 'Principal Component Analysis'],

    'Score': [acc_log_reg, acc_svc,acc_ANN ,
              acc_knn, acc_gnb,acc_PCA ]
    })

models.sort_values(by='Score', ascending=False)
